# %% [markdown]
# <a href="https://colab.research.google.com/github/bajpaidevharsh/bicep_curl_mediapipe/blob/main/procedure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **started first by import mediapipe**

# %% [markdown]
# **started by drawing the pose landmarks on the image**

# %% [markdown]
# **before**

# %%
from google.colab.patches import cv2_imshow
import cv2
img=cv2.imread('/content/orignal_image.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=327x727>

# %% [markdown]
# **after**

# %%
img=cv2.imread('/content/after+landmark.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=306x781>

# %% [markdown]
# **the video is left aligned therfore we take only 11 13 and 15 of all landmarks**

# %%
img=cv2.imread('/content/mediapipe_pose.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=425x407>

# %% [markdown]
# **we measure the curl according to the angle and count the curl**

# %%
img=cv2.imread('/content/pose_estimator.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=501x932>
